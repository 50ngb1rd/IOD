# %% [markdown]
# # Assingment 1 : Understanding the impact of COVID-19 cases on investor sentiments in the S&P 500

# %% [markdown]
# In early 2020, the rise of COVID-19 cases has been reported to cause a drastic change in  investing patterns, leading to changes in stock prices and trading volumes. For example, during an increase in COVID cases, it was reported that stocks within the travel industry fell, and stocks within the tech industry rose. <br>
#
#
# Drastic changes in  investing patterns are often related to changed investor sentiments for a particular industry/stock due external market events. . With this in mind, this notebook will attempt to answer the below <b>business question <b>:
# <br><br>
# <b><i> How does the change in COVID cases impact investor sentiment relayed by investing patterns and what is the resultant impact on the stock market?

# %% [markdown]
# BRK.B
# BSX
# GD
# BF.B are excluded

# %% [markdown]
# I have broken down the business question into 2 key parts:<br>
# 1) Understand the impact on investor sentiment and investing patterns to changes in COVID 19 cases across different industries and stocks <br>
# 2) Understand the impact on investor sentiment and investing patterns to changes in COVID 19 cases on market volatility and trading volume <br>

# %% [markdown]
# ### Preparing the dataset

# %% [markdown]
# For this assignment, I have used data from the S&P 500 (USA stock index) and we will therefore be understanding the impact on investors in the S&P 500 (both US and non-US investors). To create the dataset, I have combined: <br>
# - S&P 500 data for all stocks from Yahoo finance from 1/1/2020 to 13/1/2021 <br>
# - COVID-19 case number dataset provided by Kaggle

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [20, 10]

# %%
sp500 = pd.read_csv('E:/IOD_data/sp500.csv')
sp500
# Out:
#     Symbol                        Name                  Sector
# 0     AAPL                  Apple Inc.  Information Technology
# 1     MSFT       Microsoft Corporation  Information Technology
# 2     AMZN             Amazon.com Inc.  Consumer Discretionary
# 3     TSLA                   Tesla Inc  Consumer Discretionary
# 4       FB       Facebook Inc. Class A  Communication Services
# ..     ...                         ...                     ...
# 496    HFC   HollyFrontier Corporation                  Energy
# 497    XRX  Xerox Holdings Corporation  Information Technology
# 498    UAA   Under Armour Inc. Class A  Consumer Discretionary
# 499     UA   Under Armour Inc. Class C  Consumer Discretionary
# 500    NWS    News Corporation Class B  Communication Services
#
# [501 rows x 3 columns]

# %%
stock_ticker = sp500['Symbol']
stock_ticker = stock_ticker.tolist()

# %%
master = pd.DataFrame(columns = ['Open', 'High','Low', 'Close', 'Volume', 'Dividends', 'Stock Splits', 'Symbol', 'Sector', 'Industry'])

for i in stock_ticker:
    stock = yf.Ticker(i)
    x = stock.history(start = '2020-01-22', end = '2021-12-06')
    x['Symbol'] = i 
    master = pd.concat([x, master])

# %%
master_list = master.reset_index()
master_list
# Out:
#             index        Open        High         Low       Close     Volume  \
# 0      2020-01-21   14.818301   14.837979   14.493596   14.601831     612200
# 1      2020-01-22   14.591992   14.710066   14.513276   14.552634     544900
# 2      2020-01-23   14.414880   14.582152   14.375522   14.473918     434800
# 3      2020-01-24   14.454239   14.454239   14.109857   14.119697     899600
# 4      2020-01-27   13.952425   14.060659   13.824511   13.873709     639000
# ...           ...         ...         ...         ...         ...        ...
# 124392 2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 124393 2021-01-08  132.429993  132.630005  130.229996  132.050003  105158200
# 124394 2021-01-11  129.190002  130.169998  128.500000  128.979996  100620900
# 124395 2021-01-12  128.500000  129.690002  126.860001  128.800003   91951100
# 124396 2021-01-13  128.759995  131.449997  128.490005  130.889999   88409200
#
#         Dividends  Stock Splits Symbol Sector Industry
# 0             0.0           0.0    NWS    NaN      NaN
# 1             0.0           0.0    NWS    NaN      NaN
# 2             0.0           0.0    NWS    NaN      NaN
# 3             0.0           0.0    NWS    NaN      NaN
# 4             0.0           0.0    NWS    NaN      NaN
# ...           ...           ...    ...    ...      ...
# 124392        0.0           0.0   AAPL    NaN      NaN
# 124393        0.0           0.0   AAPL    NaN      NaN
# 124394        0.0           0.0   AAPL    NaN      NaN
# 124395        0.0           0.0   AAPL    NaN      NaN
# 124396        0.0           0.0   AAPL    NaN      NaN
#
# [124397 rows x 11 columns]

# %%
master_list = master_list.rename(columns = {'index':'Date','Company': 'Symbol'})
master_list
# Out:
#              Date        Open        High         Low       Close     Volume  \
# 0      2020-01-21   14.818301   14.837979   14.493596   14.601831     612200
# 1      2020-01-22   14.591992   14.710066   14.513276   14.552634     544900
# 2      2020-01-23   14.414880   14.582152   14.375522   14.473918     434800
# 3      2020-01-24   14.454239   14.454239   14.109857   14.119697     899600
# 4      2020-01-27   13.952425   14.060659   13.824511   13.873709     639000
# ...           ...         ...         ...         ...         ...        ...
# 124392 2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 124393 2021-01-08  132.429993  132.630005  130.229996  132.050003  105158200
# 124394 2021-01-11  129.190002  130.169998  128.500000  128.979996  100620900
# 124395 2021-01-12  128.500000  129.690002  126.860001  128.800003   91951100
# 124396 2021-01-13  128.759995  131.449997  128.490005  130.889999   88409200
#
#         Dividends  Stock Splits Symbol Sector Industry
# 0             0.0           0.0    NWS    NaN      NaN
# 1             0.0           0.0    NWS    NaN      NaN
# 2             0.0           0.0    NWS    NaN      NaN
# 3             0.0           0.0    NWS    NaN      NaN
# 4             0.0           0.0    NWS    NaN      NaN
# ...           ...           ...    ...    ...      ...
# 124392        0.0           0.0   AAPL    NaN      NaN
# 124393        0.0           0.0   AAPL    NaN      NaN
# 124394        0.0           0.0   AAPL    NaN      NaN
# 124395        0.0           0.0   AAPL    NaN      NaN
# 124396        0.0           0.0   AAPL    NaN      NaN
#
# [124397 rows x 11 columns]

# %%
master_stock_list = pd.merge(master_list,sp500, on ='Symbol')

# %%
master_stock_list
# Out:
#              Date        Open        High         Low       Close     Volume  \
# 0      2020-01-21   14.818301   14.837979   14.493596   14.601831     612200
# 1      2020-01-22   14.591992   14.710066   14.513276   14.552634     544900
# 2      2020-01-23   14.414880   14.582152   14.375522   14.473918     434800
# 3      2020-01-24   14.454239   14.454239   14.109857   14.119697     899600
# 4      2020-01-27   13.952425   14.060659   13.824511   13.873709     639000
# ...           ...         ...         ...         ...         ...        ...
# 124392 2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 124393 2021-01-08  132.429993  132.630005  130.229996  132.050003  105158200
# 124394 2021-01-11  129.190002  130.169998  128.500000  128.979996  100620900
# 124395 2021-01-12  128.500000  129.690002  126.860001  128.800003   91951100
# 124396 2021-01-13  128.759995  131.449997  128.490005  130.889999   88409200
#
#         Dividends  Stock Splits Symbol Sector_x Industry  \
# 0             0.0           0.0    NWS      NaN      NaN
# 1             0.0           0.0    NWS      NaN      NaN
# 2             0.0           0.0    NWS      NaN      NaN
# 3             0.0           0.0    NWS      NaN      NaN
# 4             0.0           0.0    NWS      NaN      NaN
# ...           ...           ...    ...      ...      ...
# 124392        0.0           0.0   AAPL      NaN      NaN
# 124393        0.0           0.0   AAPL      NaN      NaN
# 124394        0.0           0.0   AAPL      NaN      NaN
# 124395        0.0           0.0   AAPL      NaN      NaN
# 124396        0.0           0.0   AAPL      NaN      NaN
#
#                             Name                Sector_y
# 0       News Corporation Class B  Communication Services
# 1       News Corporation Class B  Communication Services
# 2       News Corporation Class B  Communication Services
# 3       News Corporation Class B  Communication Services
# 4       News Corporation Class B  Communication Services
# ...                          ...                     ...
# 124392                Apple Inc.  Information Technology
# 124393                Apple Inc.  Information Technology
# 124394                Apple Inc.  Information Technology
# 124395                Apple Inc.  Information Technology
# 124396                Apple Inc.  Information Technology
#
# [124397 rows x 13 columns]

# %%
master_stock_list = master_stock_list.drop(columns = ['Sector_x'])

# %%
master_stock_list
# Out:
#              Date        Open        High         Low       Close     Volume  \
# 0      2020-01-21   14.818301   14.837979   14.493596   14.601831     612200
# 1      2020-01-22   14.591992   14.710066   14.513276   14.552634     544900
# 2      2020-01-23   14.414880   14.582152   14.375522   14.473918     434800
# 3      2020-01-24   14.454239   14.454239   14.109857   14.119697     899600
# 4      2020-01-27   13.952425   14.060659   13.824511   13.873709     639000
# ...           ...         ...         ...         ...         ...        ...
# 124392 2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 124393 2021-01-08  132.429993  132.630005  130.229996  132.050003  105158200
# 124394 2021-01-11  129.190002  130.169998  128.500000  128.979996  100620900
# 124395 2021-01-12  128.500000  129.690002  126.860001  128.800003   91951100
# 124396 2021-01-13  128.759995  131.449997  128.490005  130.889999   88409200
#
#         Dividends  Stock Splits Symbol Industry                      Name  \
# 0             0.0           0.0    NWS      NaN  News Corporation Class B
# 1             0.0           0.0    NWS      NaN  News Corporation Class B
# 2             0.0           0.0    NWS      NaN  News Corporation Class B
# 3             0.0           0.0    NWS      NaN  News Corporation Class B
# 4             0.0           0.0    NWS      NaN  News Corporation Class B
# ...           ...           ...    ...      ...                       ...
# 124392        0.0           0.0   AAPL      NaN                Apple Inc.
# 124393        0.0           0.0   AAPL      NaN                Apple Inc.
# 124394        0.0           0.0   AAPL      NaN                Apple Inc.
# 124395        0.0           0.0   AAPL      NaN                Apple Inc.
# 124396        0.0           0.0   AAPL      NaN                Apple Inc.
#
#                       Sector_y
# 0       Communication Services
# 1       Communication Services
# 2       Communication Services
# 3       Communication Services
# 4       Communication Services
# ...                        ...
# 124392  Information Technology
# 124393  Information Technology
# 124394  Information Technology
# 124395  Information Technology
# 124396  Information Technology
#
# [124397 rows x 12 columns]

# %%
covid_19 = pd.read_csv("E:/IOD_data/covid_19/covid_19_data.csv")

# %%
covid_19
# Out:
#            SNo       Date     Province/State Country/Region  \
# 0            1  1/22/2020              Anhui         Non-US
# 1            2  1/22/2020            Beijing         Non-US
# 2            3  1/22/2020          Chongqing         Non-US
# 3            4  1/22/2020             Fujian         Non-US
# 4            5  1/22/2020              Gansu         Non-US
# ...        ...        ...                ...            ...
# 172475  172476  12/6/2020  Zaporizhia Oblast         Non-US
# 172476  172477  12/6/2020            Zeeland         Non-US
# 172477  172478  12/6/2020           Zhejiang         Non-US
# 172478  172479  12/6/2020    Zhytomyr Oblast         Non-US
# 172479  172480  12/6/2020       Zuid-Holland         Non-US
#
#         Confirmed US cases  Confirmed non-US cases  Total cases  \
# 0                        0                       1            1
# 1                        0                      14           14
# 2                        0                       6            6
# 3                        0                       1            1
# 4                        0                       0            0
# ...                    ...                     ...          ...
# 172475                   0                   36539        36539
# 172476                   0                    6710         6710
# 172477                   0                    1295         1295
# 172478                   0                   31967        31967
# 172479                   0                  154813       154813
#
#         Confirmed US deaths  Confirmed non-US deaths  Confirmed US recoveries  \
# 0                         0                        0                        0
# 1                         0                        0                        0
# 2                         0                        0                        0
# 3                         0                        0                        0
# 4                         0                        0                        0
# ...                     ...                      ...                      ...
# 172475                    0                      337                        0
# 172476                    0                      104                        0
# 172477                    0                        1                        0
# 172478                    0                      531                        0
# 172479                    0                     2414                        0
#
#         Confirmed non-US recoveries      Last Update
# 0                                 0  1/22/2020 17:00
# 1                                 0  1/22/2020 17:00
# 2                                 0  1/22/2020 17:00
# 3                                 0  1/22/2020 17:00
# 4                                 0  1/22/2020 17:00
# ...                             ...              ...
# 172475                         6556   12/7/2020 5:26
# 172476                            0   12/7/2020 5:26
# 172477                         1288   12/7/2020 5:26
# 172478                        22263   12/7/2020 5:26
# 172479                            0   12/7/2020 5:26
#
# [172480 rows x 12 columns]

# %%
cov = covid_19.drop(columns =['SNo','Province/State', 'Country/Region'])
cov_grouped = cov.groupby('Date').sum()
cov_grouped = cov_grouped.reset_index()
cov_grouped["Date"] = pd.to_datetime(cov_grouped["Date"])
cov_grouped["Date"].max()
# Out:
# Timestamp('2020-12-06 00:00:00')

# %%
cov_grouped
# Out:
#           Date  Confirmed US cases  Confirmed non-US cases  Total cases  \
# 0   2020-01-22                   1                     554          555
# 1   2020-01-23                   1                     652          653
# 2   2020-01-24                   2                     939          941
# 3   2020-01-25                   2                    1436         1438
# 4   2020-01-26                   5                    2113         2118
# ..         ...                 ...                     ...          ...
# 315 2020-09-05             6247538                20656451     26903989
# 316 2020-09-06             6279314                20857152     27136466
# 317 2020-09-07             6303477                21061760     27365237
# 318 2020-09-08             6330007                21273685     27603692
# 319 2020-09-09             6364557                21533397     27897954
#
#      Confirmed US deaths  Confirmed non-US deaths  Confirmed US recoveries  \
# 0                      0                       17                        0
# 1                      0                       18                        0
# 2                      0                       26                        0
# 3                      0                       42                        0
# 4                      0                       56                        0
# ..                   ...                      ...                      ...
# 315               188546                   691161                  2302187
# 316               188950                   694805                  2315995
# 317               189217                   703658                  2333551
# 318               189660                   708114                  2359111
# 319               190868                   713265                  2387479
#
#      Confirmed non-US recoveries
# 0                             28
# 1                             30
# 2                             36
# 3                             39
# 4                             52
# ..                           ...
# 315                     15622469
# 316                     15829977
# 317                     15998892
# 318                     16172978
# 319                     16397322
#
# [320 rows x 8 columns]

# %%
cov_grouped = cov_grouped.sort_values(by =['Date'])

# %%
stocks_covid = pd.merge(cov_grouped,master_stock_list, on = 'Date')

# %%
stocks_covid = stocks_covid.sort_values(by = ['Date'])

# %%
stocks_covid
# Out:
#              Date  Confirmed US cases  Confirmed non-US cases  Total cases  \
# 0      2020-01-22                   1                     554          555
# 339    2020-01-22                   1                     554          555
# 338    2020-01-22                   1                     554          555
# 337    2020-01-22                   1                     554          555
# 336    2020-01-22                   1                     554          555
# ...           ...                 ...                     ...          ...
# 110532 2020-12-04            14367462                51531979     65899441
# 110531 2020-12-04            14367462                51531979     65899441
# 110530 2020-12-04            14367462                51531979     65899441
# 110543 2020-12-04            14367462                51531979     65899441
# 110873 2020-12-04            14367462                51531979     65899441
#
#         Confirmed US deaths  Confirmed non-US deaths  Confirmed US recoveries  \
# 0                         0                       17                        0
# 339                       0                       17                        0
# 338                       0                       17                        0
# 337                       0                       17                        0
# 336                       0                       17                        0
# ...                     ...                      ...                      ...
# 110532               278932                  1239738                  5470389
# 110531               278932                  1239738                  5470389
# 110530               278932                  1239738                  5470389
# 110543               278932                  1239738                  5470389
# 110873               278932                  1239738                  5470389
#
#         Confirmed non-US recoveries        Open        High         Low  \
# 0                                28   14.591992   14.710066   14.513276
# 339                              28  112.619933  113.888247  112.530056
# 338                              28   80.964662   81.448784   80.441808
# 337                              28  274.890015  281.799988  274.890015
# 336                              28   65.860001   67.489998   65.419998
# ...                             ...         ...         ...         ...
# 110532                     36881632  280.250000  289.899994  276.559998
# 110531                     36881632  103.330002  105.209999  103.330002
# 110530                     36881632   27.900000   29.080000   27.850000
# 110543                     36881632   48.697332   49.153095   48.390186
# 110873                     36881632  122.599998  122.860001  121.519997
#
#              Close    Volume  Dividends  Stock Splits Symbol Industry  \
# 0        14.552634    544900        0.0           0.0    NWS      NaN
# 339     112.939507   2423100        0.0           0.0     EA      NaN
# 338      80.499901   2410600        0.0           0.0    SYY      NaN
# 337     279.309998    832500        0.0           0.0   ALGN      NaN
# 336      66.760002   8734600        0.0           0.0    CNC      NaN
# ...            ...       ...        ...           ...    ...      ...
# 110532  279.540009   2707400        0.0           0.0   ULTA      NaN
# 110531  104.190002   1370200        0.0           0.0   AKAM      NaN
# 110530   28.950001   7880300        0.0           0.0     FE      NaN
# 110543   49.004475   1892900        0.0           0.0    VTR      NaN
# 110873  122.250000  78260400        0.0           0.0   AAPL      NaN
#
#                             Name                Sector_y
# 0       News Corporation Class B  Communication Services
# 339         Electronic Arts Inc.  Communication Services
# 338            Sysco Corporation        Consumer Staples
# 337        Align Technology Inc.             Health Care
# 336          Centene Corporation             Health Care
# ...                          ...                     ...
# 110532           Ulta Beauty Inc  Consumer Discretionary
# 110531  Akamai Technologies Inc.  Information Technology
# 110530         FirstEnergy Corp.               Utilities
# 110543               Ventas Inc.             Real Estate
# 110873                Apple Inc.  Information Technology
#
# [110874 rows x 19 columns]

# %%
stocks_covid.to_csv('E:/IOD_data/stocks_covid_2.csv', index = False, header = True)

# %% [markdown]
# ###  Checking data quality

# %%
df = pd.read_csv('E:/IOD_data/stocks_covid.csv')

# %%
df.sample(10)
# Out:
#              Date  Confirmed US cases  Confirmed non-US cases  Total cases  \
# 87948   11/6/2020             9799843                39627389     49427232
# 85399    6/8/2020             1961728                 5157608      7119336
# 66940   2/24/2020                  53                   79517        79570
# 73061   8/24/2020             5741513                17930736     23672249
# 42846   3/19/2020               13680                  228995       242675
# 37193    9/8/2020             6330007                21273685     27603692
# 1032    8/17/2020             5440803                16462519     21903322
# 101088  2/24/2020                  53                   79517        79570
# 10032   3/23/2020               43697                  334799       378496
# 89576    4/8/2020              429370                 1082555      1511925
#
#         Confirmed US deaths  Confirmed non-US deaths  Confirmed US recoveries  \
# 87948                236801                  1007228                  3810791
# 85399                111014                   295538                   518522
# 66940                     0                     2629                        5
# 73061                177257                   636161                  2020774
# 42846                   200                     9667                      108
# 37193                189660                   708114                  2359111
# 1032                 170500                   603854                  1865580
# 101088                    0                     2629                        5
# 10032                   552                    15945                        0
# 89576                 14699                    73652                    23559
#
#         Confirmed non-US recoveries        Open        High         Low  \
# 87948                      28697444   96.698692   98.849104   95.822602
# 85399                       2774847   49.238163   52.841427   49.238163
# 66940                         25222  332.298789  344.846072  331.092903
# 73061                      13316664  335.726517  341.485507  335.439054
# 42846                         84854    6.374010    6.881938    6.125025
# 37193                      16172978   87.167483   87.416021   85.725961
# 1032                       12024494   94.009770   95.953304   93.980175
# 101088                        25222  143.729996  143.970001  139.429993
# 10032                        100943  118.796361  118.796361  106.351956
# 89576                        305492  111.099422  112.682790  107.707893
#
#              Close  Return    Volume  Dividends  Stock Splits Symbol  \
# 87948    96.648918  0.0271   1684000        0.0           0.0    RSG
# 85399    52.296070 -0.0057   1510300        0.0           0.0    REG
# 66940   340.750030 -0.0014    286100        0.0           0.0   MKTX
# 73061   341.396301  0.0159    416700        0.0           0.0    NOC
# 42846     6.453685  0.0162  98993700        0.0           0.0     GE
# 37193    85.954613 -0.0164   1463100        0.0           0.0   EXPD
# 1032     95.055527  0.0166   7251400        0.0           0.0   ABBV
# 101088  141.949997 -0.0680   1431300        0.0           0.0    URI
# 10032   111.902275 -0.0939   1195400        0.0           0.0    ARE
# 89576   111.549019 -0.0132    956400        0.0           0.0    SJM
#
#         Industry                                         Name  \
# 87948        NaN                       Republic Services Inc.
# 85399        NaN                  Regency Centers Corporation
# 66940        NaN                    MarketAxess Holdings Inc.
# 73061        NaN                 Northrop Grumman Corporation
# 42846        NaN                     General Electric Company
# 37193        NaN  Expeditors International of Washington Inc.
# 1032         NaN                                  AbbVie Inc.
# 101088       NaN                          United Rentals Inc.
# 10032        NaN         Alexandria Real Estate Equities Inc.
# 89576        NaN                         J.M. Smucker Company
#
#                 Sector_y
# 87948        Industrials
# 85399        Real Estate
# 66940         Financials
# 73061        Industrials
# 42846        Industrials
# 37193        Industrials
# 1032         Health Care
# 101088       Industrials
# 10032        Real Estate
# 89576   Consumer Staples

# %%
# dropping dividends and stock splits as not necessary
df =df.drop(columns=['Dividends','Stock Splits'])
df
# Out:
#               Date  Confirmed US cases  Confirmed non-US cases  Total cases  \
# 0        1/22/2020                   1                     554          555
# 1        1/23/2020                   1                     652          653
# 2        1/24/2020                   2                     939          941
# 3        1/27/2020                   5                    2922         2927
# 4        1/28/2020                   5                    5573         5578
# ...            ...                 ...                     ...          ...
# 110869  11/30/2020            13541221                49737805     63279026
# 110870   12/1/2020            13721858                50162127     63883985
# 110871   12/2/2020            13921913                50608604     64530517
# 110872   12/3/2020            14139577                51081463     65221040
# 110873   12/4/2020            14367462                51531979     65899441
#
#         Confirmed US deaths  Confirmed non-US deaths  Confirmed US recoveries  \
# 0                         0                       17                        0
# 1                         0                       18                        0
# 2                         0                       26                        0
# 3                         0                       82                        0
# 4                         0                      131                        0
# ...                     ...                      ...                      ...
# 110869               268045                  1200413                  5146319
# 110870               270642                  1210664                  5226581
# 110871               273446                  1220296                  5322128
# 110872               276325                  1229935                  5404018
# 110873               278932                  1239738                  5470389
#
#         Confirmed non-US recoveries        Open        High         Low  \
# 0                                28   89.216273   89.910638   89.117072
# 1                                30   88.898841   89.255945   87.946567
# 2                                36   88.730201   88.740122   86.875253
# 3                                61   85.843629   86.468556   85.516282
# 4                               107   86.151139   86.776074   85.496454
# ...                             ...         ...         ...         ...
# 110869                     35413034  162.479996  162.479996  159.649994
# 110870                     35808353  161.639999  162.479996  159.990005
# 110871                     36174190  161.000000  161.839996  158.479996
# 110872                     36528073  158.580002  159.089996  156.440002
# 110873                     36881632  157.160004  158.220001  156.660004
#
#              Close  Return   Volume Symbol  Industry  \
# 0        89.404739  0.0000  1665800      A       NaN
# 1        88.353264 -0.0073  1228300      A       NaN
# 2        87.549782 -0.0058  1164500      A       NaN
# 3        85.863464 -0.0256  1868000      A       NaN
# 4        86.478485  0.0036  1652200      A       NaN
# ...            ...     ...      ...    ...       ...
# 110869  160.380005  0.0018  4533900    ZTS       NaN
# 110870  161.360001  0.0000  1964400    ZTS       NaN
# 110871  158.949997 -0.0039  1529400    ZTS       NaN
# 110872  157.070007 -0.0170  2308200    ZTS       NaN
# 110873  157.949997 -0.0055  1497100    ZTS       NaN
#
#                              Name     Sector_y
# 0       Agilent Technologies Inc.  Health Care
# 1       Agilent Technologies Inc.  Health Care
# 2       Agilent Technologies Inc.  Health Care
# 3       Agilent Technologies Inc.  Health Care
# 4       Agilent Technologies Inc.  Health Care
# ...                           ...          ...
# 110869        Zoetis Inc. Class A  Health Care
# 110870        Zoetis Inc. Class A  Health Care
# 110871        Zoetis Inc. Class A  Health Care
# 110872        Zoetis Inc. Class A  Health Care
# 110873        Zoetis Inc. Class A  Health Care
#
# [110874 rows x 18 columns]

# %%
# checking data types to ensure correctness
df.dtypes
# Out:
# Date                            object
# Confirmed US cases               int64
# Confirmed non-US cases           int64
# Total cases                      int64
# Confirmed US deaths              int64
# Confirmed non-US deaths          int64
# Confirmed US recoveries          int64
# Confirmed non-US recoveries      int64
# Open                           float64
# High                           float64
# Low                            float64
# Close                          float64
# Return                         float64
# Volume                           int64
# Symbol                          object
# Industry                       float64
# Name                            object
# Sector_y                        object
# dtype: object

# %%
# changing date to datetime and renaming sector
df['Date'] = pd.to_datetime(df['Date'])
df = df.rename(columns={'Sector_y':'Sector'})
df = df.drop(columns ='Industry')
df.dtypes
# Out:
# Date                           datetime64[ns]
# Confirmed US cases                      int64
# Confirmed non-US cases                  int64
# Total cases                             int64
# Confirmed US deaths                     int64
# Confirmed non-US deaths                 int64
# Confirmed US recoveries                 int64
# Confirmed non-US recoveries             int64
# Open                                  float64
# High                                  float64
# Low                                   float64
# Close                                 float64
# Return                                float64
# Volume                                  int64
# Symbol                                 object
# Name                                   object
# Sector                                 object
# dtype: object

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date                           0
# Confirmed US cases             0
# Confirmed non-US cases         0
# Total cases                    0
# Confirmed US deaths            0
# Confirmed non-US deaths        0
# Confirmed US recoveries        0
# Confirmed non-US recoveries    0
# Open                           0
# High                           0
# Low                            0
# Close                          0
# Return                         0
# Volume                         0
# Symbol                         0
# Name                           0
# Sector                         0
# dtype: int64

# %% [markdown]
# ### Performing EDA

# %% [markdown]
# Here we want to understand the stock with the highest and lowest one day return

# %%
# checking range for daily returns
df['Return'].idxmax()
highest_return = df.iloc[df['Return'].idxmax()]
print(f"The stock with the highest daily return is: {highest_return['Name']} with a return of {highest_return['Return']}")

lowest_return = df.iloc[df['Return'].idxmin()]
print(f"The stock with the lowest daily return is: {lowest_return['Name']} with a return of {lowest_return['Return']}")
# Out:
# The stock with the highest daily return is: American Airlines Group Inc. with a return of 0.4902
# The stock with the lowest daily return is: Diamondback Energy Inc. with a return of -0.4726

# %% [markdown]
# What are the stocks with the top 10 daily returns?

# %%
# checking max daily returns
top_10 = df.loc[:,'Return']
top_10_returns = top_10.nlargest(n=20, keep='first')
top_10_returns_df = df.loc[top_10_returns.index,['Return','Name','Sector']]
top_10_returns_df
# Out:
#        Return                                 Name                  Sector
# 315    0.4902         American Airlines Group Inc.             Industrials
# 70957  0.4882  Norwegian Cruise Line Holdings Ltd.  Consumer Discretionary
# 13520  0.4453                          Biogen Inc.             Health Care
# 17923  0.4045                 Carnival Corporation  Consumer Discretionary
# 34389  0.3943                  Enphase Energy Inc.  Information Technology
# 31971  0.3928                   DXC Technology Co.  Information Technology
# 45135  0.3775                             Gap Inc.  Consumer Discretionary
# 59587  0.3686                        L Brands Inc.  Consumer Discretionary
# 12032  0.3658                       Boeing Company             Industrials
# 31968  0.3655                   DXC Technology Co.  Information Technology
# 49891  0.3557           Host Hotels & Resorts Inc.             Real Estate
# 5297   0.3553                Align Technology Inc.             Health Care
# 59499  0.3538                        L Brands Inc.  Consumer Discretionary
# 84903  0.3503                Royal Caribbean Group  Consumer Discretionary
# 17763  0.3398                 Carnival Corporation  Consumer Discretionary
# 71117  0.3324  Norwegian Cruise Line Holdings Ltd.  Consumer Discretionary
# 77406  0.3280     Occidental Petroleum Corporation                  Energy
# 17761  0.3279                 Carnival Corporation  Consumer Discretionary
# 90169  0.3235                SL Green Realty Corp.             Real Estate
# 9157   0.3215                   Apache Corporation                  Energy

# %% [markdown]
# What are the stocks with the bottom 10 returns?

# %%
# checking min daily returns
bottom_10 = df.loc[:,'Return']
bottom_10_returns = bottom_10.nsmallest(n=20, keep='first')
bottom_10_returns_df = df.loc[bottom_10_returns.index,['Return','Name','Sector']]
bottom_10_returns_df
# Out:
#        Return                                 Name                  Sector
# 37954 -0.4726              Diamondback Energy Inc.                  Energy
# 9134  -0.4173                   Apache Corporation                  Energy
# 31738 -0.3581             Devon Energy Corporation                  Energy
# 77344 -0.3455     Occidental Petroleum Corporation                  Energy
# 84004 -0.3450    Pioneer Natural Resources Company                  Energy
# 68948 -0.3404             Marathon Oil Corporation                  Energy
# 34624 -0.3292                   EOG Resources Inc.                  Energy
# 45946 -0.3273                  Halliburton Company                  Energy
# 17770 -0.3236                 Carnival Corporation  Consumer Discretionary
# 47278 -0.3210                     Hess Corporation                  Energy
# 70949 -0.3095  Norwegian Cruise Line Holdings Ltd.  Consumer Discretionary
# 70960 -0.2944  Norwegian Cruise Line Holdings Ltd.  Consumer Discretionary
# 73166 -0.2913                             NOV Inc.                  Energy
# 89776 -0.2886                      Schlumberger NV                  Energy
# 39380 -0.2869                    FirstEnergy Corp.               Utilities
# 76274 -0.2802                           ONEOK Inc.                  Energy
# 13523 -0.2718                          Biogen Inc.             Health Care
# 64293 -0.2505  Marriott International Inc. Class A  Consumer Discretionary
# 84906 -0.2474                Royal Caribbean Group  Consumer Discretionary
# 31745 -0.2427             Devon Energy Corporation                  Energy

# %% [markdown]
# ### Sector analysis

# %% [markdown]
# To answer the business question, let's look at how COVID 19 has impacted the different sectors in the stock markets. In order to do this, I have calculated the weighted daily return for each sector for each day. <br>
# What are the sectors in the S&P 500 and what are their components? --> https://www.spglobal.com/spdji/en/landing/investment-themes/sectors/

# %%
# create list for the loop
sector_list = df['Sector'].unique()
date_list = df['Date'].unique()

# %%
# used to store the total volume for each sector each day
df['Total Volume per Sector'] = 0

# %%
# creating a dataset grouped by date and sector with the sum of volume for each sector
df_sector_vol = df.groupby(['Date','Sector']).Volume.sum()
df_sector_vol = df_sector_vol.reset_index()

# %%
# loop to populate the total volume for each sector each day in the original dataframe 
for i in date_list:
    df_s = df_sector_vol[df_sector_vol['Date'] == i]
    for j in sector_list:
        vol = df_s[df_s['Sector'] == j].iloc[0]['Volume']
        selection = (df['Date'] == i)  & (df['Sector'] == j)
        df.loc[selection,['Total Volume per Sector']] = vol

# %%
# get the weighted daily return for each sector
df['Volume Weights'] = df['Volume'] / df['Total Volume per Sector'] 
df['Weighted_Daily_Return'] = df['Return'] * df['Volume Weights']

# %%
# by summing the daily weighted return for each sector, we get the average weighted return for each sector in each day
df_sector = df.groupby(['Date','Sector']).Weighted_Daily_Return.sum()

# %%
df_sector = df_sector.reset_index()

# %% [markdown]
# #### Sectors with lowest and highest returns

# %% [markdown]
# Now that we have the weighted returns for each sector, we will investigate which sectors showed the lowest and highest return during the pandemic

# %%
# checking the lowest returns, which go to negative
df_sector.nsmallest(10, 'Weighted_Daily_Return')
# Out:
#       index       Date                  Sector  Weighted_Daily_Return
# 355     355 2020-03-09                  Energy              -0.232121
# 1396   1396 2020-07-22               Utilities              -0.171831
# 551     551 2020-04-02  Consumer Discretionary              -0.123675
# 435     435 2020-03-18             Industrials              -0.116218
# 430     430 2020-03-18  Consumer Discretionary              -0.110446
# 1079   1079 2020-06-11  Consumer Discretionary              -0.106038
# 432     432 2020-03-18                  Energy              -0.104458
# 408     408 2020-03-16  Consumer Discretionary              -0.103866
# 386     386 2020-03-12  Consumer Discretionary              -0.100053
# 1081   1081 2020-06-11                  Energy              -0.099906

# %%
# checking on the highest returns
df_sector.nlargest(10, 'Weighted_Daily_Return')
# Out:
#       index       Date                  Sector  Weighted_Daily_Return
# 1029   1029 2020-06-04             Industrials               0.243345
# 2242   2242 2020-11-09             Real Estate               0.228407
# 2234   2234 2020-11-09  Consumer Discretionary               0.189878
# 2239   2239 2020-11-09             Industrials               0.180879
# 1037   1037 2020-06-05                  Energy               0.179083
# 474     474 2020-03-24  Consumer Discretionary               0.178343
# 1040   1040 2020-06-05             Industrials               0.170115
# 553     553 2020-04-02                  Energy               0.166299
# 2236   2236 2020-11-09                  Energy               0.161611
# 479     479 2020-03-24             Industrials               0.149951

# %% [markdown]
# From the above we can see, that some sectors both have the highest and lowest returns, which indicates high volatility (very large changes). Let's demonstrate throughs some graphs

# %%
# creating the dataframes that are specific for each sector
df_energy_tf = df_sector.loc[:,'Sector'] == 'Energy'
df_energy = df_sector.loc[df_energy_tf]

df_tech_tf = df_sector.loc[:,'Sector'] == 'Information Technology'
df_tech = df_sector.loc[df_tech_tf]

df_ind_tf = df_sector.loc[:,'Sector'] == 'Industrials'
df_ind = df_sector.loc[df_ind_tf]

df_health_tf = df_sector.loc[:,'Sector'] == 'Health Care'
df_health = df_sector.loc[df_health_tf]

df_fin_tf = df_sector.loc[:,'Sector'] == 'Financials'
df_fin = df_sector.loc[df_fin_tf]

df_cd_tf = df_sector.loc[:,'Sector'] == 'Consumer Discretionary'
df_cd = df_sector.loc[df_cd_tf]

df_cserv_tf = df_sector.loc[:,'Sector'] == 'Communication Services'
df_cserv = df_sector.loc[df_cserv_tf]

df_cs_tf = df_sector.loc[:,'Sector'] == 'Consumer Staples'
df_cs = df_sector.loc[df_cs_tf]

df_ut_tf = df_sector.loc[:,'Sector'] == 'Utilities'
df_ut = df_sector.loc[df_ut_tf]

df_re_tf = df_sector.loc[:,'Sector'] == 'Real Estate'
df_re = df_sector.loc[df_re_tf]

df_mat_tf = df_sector.loc[:,'Sector'] == 'Materials'
df_mat = df_sector.loc[df_mat_tf]

# %%
plt.rcParams['figure.figsize'] = [20, 10]

# %%
# plotting all the sectors, x axis = time, y axis = daily weighted returns
fig, axs = plt.subplots(6,2, sharey = True, sharex = False)
plt.subplots_adjust(hspace = 0.7)
axs[0,0].plot(df_tech['Date'], df_tech['Weighted_Daily_Return'])
axs[0,0].set_title('Information Technology')
axs[0,1].plot(df_energy['Date'], df_energy['Weighted_Daily_Return'])
axs[0,1].set_title('Energy')
axs[1,0].plot(df_ind['Date'], df_ind['Weighted_Daily_Return'])
axs[1,0].set_title('Industrials')
axs[1,1].plot(df_health['Date'], df_health['Weighted_Daily_Return'])
axs[1,1].set_title('Health Care')
axs[2,0].plot(df_fin['Date'], df_fin['Weighted_Daily_Return'])
axs[2,0].set_title('Financials')
axs[2,1].plot(df_cd['Date'], df_cd['Weighted_Daily_Return'])
axs[2,1].set_title('Consumer Discretionary')
axs[3,0].plot(df_cserv['Date'], df_cserv['Weighted_Daily_Return'])
axs[3,0].set_title('Consumer Services')
axs[3,1].plot(df_cs['Date'], df_cs['Weighted_Daily_Return'])
axs[3,1].set_title('Consumer Staples')
axs[4,0].plot(df_ut['Date'], df_ut['Weighted_Daily_Return'])
axs[4,0].set_title('Utilities')
axs[4,1].plot(df_re['Date'], df_re['Weighted_Daily_Return'])
axs[4,1].set_title('Real Estate')
axs[5,0].plot(df_mat['Date'], df_mat['Weighted_Daily_Return'])
axs[5,0].set_title('Materials')
# Out:
# Text(0.5, 1.0, 'Materials')

# %% [markdown]
# Some observations from above: <br>
# - The energy, industrials, consumer discretionary, financials  show high volatility during the pandemic <br>
# - The materials, utilities, real estate and information technology sectors have medium volatility with some spikes in returns but not as frequent as the highly volatile sectors <br>
# - The consumer services and consumer staples sectors show stability, with low volatility <br>
# - The health care sector returns are also fairly stable, which is an interesting observation as the news of the COVID vaccine should have caused some volatility <br>
# <br>
#
# We can also see that some peaks and troughs of certain sectors <b> occur around the same time </b>. Let's take a closer look

# %%
fig2, ax = plt.subplots()

ax.plot(df_fin['Date'],df_fin['Weighted_Daily_Return'], label = 'Information Technology')
ax.plot(df_energy['Date'], df_energy['Weighted_Daily_Return'], label = 'Energy')
ax.plot(df_cd['Date'], df_cd['Weighted_Daily_Return'], label = 'Consumer Discretionary')
ax.plot(df_ind['Date'], df_ind['Weighted_Daily_Return'], label = 'Industrials')
ax.legend()

plt.show()

# %% [markdown]
# Look at all that volatility! As we can see, the patterns of the ups and downs almost match, indicating that certain factors affect all these sectors in the same way

# %%
# renaming columns to make them easier to work with
df = df.rename(columns={'Confirmed US cases':'US_cases','Confirmed non-US cases':'non_US_cases','Total cases':'total_cases','Confirmed US deaths':'US_deaths','Confirmed non-US deaths':'non_US_deaths','Confirmed US recoveries':'US_recoveries','Confirmed non-US recoveries':'non_US_recoveries'})
df
# Out:
#              Date  US_cases  non_US_cases  total_cases  US_deaths  \
# 0      2020-01-22         1           554          555          0
# 1      2020-01-23         1           652          653          0
# 2      2020-01-24         2           939          941          0
# 3      2020-01-27         5          2922         2927          0
# 4      2020-01-28         5          5573         5578          0
# ...           ...       ...           ...          ...        ...
# 110869 2020-11-30  13541221      49737805     63279026     268045
# 110870 2020-12-01  13721858      50162127     63883985     270642
# 110871 2020-12-02  13921913      50608604     64530517     273446
# 110872 2020-12-03  14139577      51081463     65221040     276325
# 110873 2020-12-04  14367462      51531979     65899441     278932
#
#         non_US_deaths  US_recoveries  non_US_recoveries        Open  \
# 0                  17              0                 28   89.216273
# 1                  18              0                 30   88.898841
# 2                  26              0                 36   88.730201
# 3                  82              0                 61   85.843629
# 4                 131              0                107   86.151139
# ...               ...            ...                ...         ...
# 110869        1200413        5146319           35413034  162.479996
# 110870        1210664        5226581           35808353  161.639999
# 110871        1220296        5322128           36174190  161.000000
# 110872        1229935        5404018           36528073  158.580002
# 110873        1239738        5470389           36881632  157.160004
#
#               High         Low       Close  Return   Volume Symbol  \
# 0        89.910638   89.117072   89.404739  0.0000  1665800      A
# 1        89.255945   87.946567   88.353264 -0.0073  1228300      A
# 2        88.740122   86.875253   87.549782 -0.0058  1164500      A
# 3        86.468556   85.516282   85.863464 -0.0256  1868000      A
# 4        86.776074   85.496454   86.478485  0.0036  1652200      A
# ...            ...         ...         ...     ...      ...    ...
# 110869  162.479996  159.649994  160.380005  0.0018  4533900    ZTS
# 110870  162.479996  159.990005  161.360001  0.0000  1964400    ZTS
# 110871  161.839996  158.479996  158.949997 -0.0039  1529400    ZTS
# 110872  159.089996  156.440002  157.070007 -0.0170  2308200    ZTS
# 110873  158.220001  156.660004  157.949997 -0.0055  1497100    ZTS
#
#                              Name       Sector  Total Volume per Sector  \
# 0       Agilent Technologies Inc.  Health Care                157519400
# 1       Agilent Technologies Inc.  Health Care                191337300
# 2       Agilent Technologies Inc.  Health Care                211788700
# 3       Agilent Technologies Inc.  Health Care                198424100
# 4       Agilent Technologies Inc.  Health Care                209225700
# ...                           ...          ...                      ...
# 110869        Zoetis Inc. Class A  Health Care                301575300
# 110870        Zoetis Inc. Class A  Health Care                227021500
# 110871        Zoetis Inc. Class A  Health Care                219816700
# 110872        Zoetis Inc. Class A  Health Care                213318700
# 110873        Zoetis Inc. Class A  Health Care                169558600
#
#         Volume Weights  Weighted_Daily_Return
# 0             0.010575               0.000000
# 1             0.006420              -0.000047
# 2             0.005498              -0.000032
# 3             0.009414              -0.000241
# 4             0.007897               0.000028
# ...                ...                    ...
# 110869        0.015034               0.000027
# 110870        0.008653               0.000000
# 110871        0.006958              -0.000027
# 110872        0.010820              -0.000184
# 110873        0.008829              -0.000049
#
# [110874 rows x 20 columns]

# %%
df_cases = df.groupby('Date').max()
df_cases = df_cases.reset_index()
df_cases
# Out:
#           Date  US_cases  non_US_cases  total_cases  US_deaths  non_US_deaths  \
# 0   2020-01-22         1           554          555          0             17
# 1   2020-01-23         1           652          653          0             18
# 2   2020-01-24         2           939          941          0             26
# 3   2020-01-27         5          2922         2927          0             82
# 4   2020-01-28         5          5573         5578          0            131
# ..         ...       ...           ...          ...        ...            ...
# 217 2020-11-30  13541221      49737805     63279026     268045        1200413
# 218 2020-12-01  13721858      50162127     63883985     270642        1210664
# 219 2020-12-02  13921913      50608604     64530517     273446        1220296
# 220 2020-12-03  14139577      51081463     65221040     276325        1229935
# 221 2020-12-04  14367462      51531979     65899441     278932        1239738
#
#      US_recoveries  non_US_recoveries         Open         High          Low  \
# 0                0                 28  3910.000000  3957.129883  3887.000000
# 1                0                 30  3930.000000  4050.000000  3930.000000
# 2                0                 36  4025.000000  4058.000000  3951.620117
# 3                0                 61  3908.000000  3984.219971  3887.000000
# 4                0                107  3960.000000  4057.949951  3915.929932
# ..             ...                ...          ...          ...          ...
# 217        5146319           35413034  4097.930176  4100.000000  3950.010010
# 218        5226581           35808353  4016.000000  4047.669922  3978.800049
# 219        5322128           36174190  3980.580078  3999.340088  3893.000000
# 220        5404018           36528073  3900.000000  4050.000000  3875.199951
# 221        5470389           36881632  3998.399902  4029.530029  3943.030029
#
#            Close  Return     Volume Symbol                 Name     Sector  \
# 0    3932.000000  0.0000  156845000    ZTS  salesforce.com inc.  Utilities
# 1    4028.239990  0.1054  104472000    ZTS  salesforce.com inc.  Utilities
# 2    3983.600098  0.0876  146537600    ZTS  salesforce.com inc.  Utilities
# 3    3946.219971  0.0396  161940000    ZTS  salesforce.com inc.  Utilities
# 4    4030.000000  0.0641  162234000    ZTS  salesforce.com inc.  Utilities
# ..           ...     ...        ...    ...                  ...        ...
# 217  3997.179932  0.0902  169410200    ZTS  salesforce.com inc.  Utilities
# 218  3994.219971  0.0518  128166800    ZTS  salesforce.com inc.  Utilities
# 219  3899.100098  0.1102   89004200    ZTS  salesforce.com inc.  Utilities
# 220  4000.000000  0.1104  169287200    ZTS  salesforce.com inc.  Utilities
# 221  3999.989990  0.1130  135020900    ZTS  salesforce.com inc.  Utilities
#
#      Total Volume per Sector  Volume Weights  Weighted_Daily_Return
# 0                  437915100        0.460783               0.000000
# 1                  455525100        0.495074               0.004990
# 2                  576418100        0.336284               0.012874
# 3                  541919200        0.362761               0.002791
# 4                  505560500        0.415594               0.006835
# ..                       ...             ...                    ...
# 217                685977200        0.252981               0.008960
# 218                568889300        0.320061               0.014019
# 219                478968100        0.383717               0.008634
# 220                493691900        0.342901               0.037856
# 221                465680300        0.339668               0.018989
#
# [222 rows x 20 columns]

# %%
fig3, (ax1,ax2) = plt.subplots(2,1, sharey = False, sharex = True)
ax1.plot(df_fin['Date'],df_fin['Weighted_Daily_Return'],label = 'Financials')
ax1.plot(df_energy['Date'], df_energy['Weighted_Daily_Return'], label = 'Energy')
ax1.plot(df_cd['Date'], df_cd['Weighted_Daily_Return'], label = 'Consumer Discretionary')
ax1.plot(df_ind['Date'], df_ind['Weighted_Daily_Return'], label = 'Industrials')
ax1.legend()
ax2.plot(df_cases['Date'], df_cases['US_cases'],label = 'US COVID cases')
ax2.plot(df_cases['Date'], df_cases['non_US_cases'],label = 'non-US COVID cases')
ax2.legend()

# %% [markdown]
# Key notes :
# - worst volatility started in March 2020, when COVID 19 was declared a pandemic and markets were panicked, causing a stock market crash (see first lowest dip) and more volatility afterwards
